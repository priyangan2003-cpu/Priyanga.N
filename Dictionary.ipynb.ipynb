# %%
d={10:"priya",20:"balaji",30:"adhira"}
print(d)
# Out:
# {10: 'priya', 20: 'balaji', 30: 'adhira'}

# %%
d={}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d={}
d[10]="balaji"
d[20]="priya"
d[30]="aadhira"
print(d)
# Out:
# {10: 'balaji', 20: 'priya', 30: 'aadhira'}

# %%
d={10:"priya",20:"balaji",30:"aadhira"}
print(d[10])
print(d[20])
print(d[30])
# Out:
# priya
# balaji
# aadhira

# %%
d={10:"priya",20:"balaji",30:"aadhira"}
for k in d:
  print(k,d[k])
# Out:
# 10 priya
# 20 balaji
# 30 aadhira

# %%
d={10:"priya",20:"balaji",30:"aadhira"}
print("old dictionary:",d)
d[99]="jothi"
print("added key-value 99:jothi pair to dictionary:",d)
# Out:
# old dictionary: {10: 'priya', 20: 'balaji', 30: 'aadhira'}
# added key-value 99:jothi pair to dictionary: {10: 'priya', 20: 'balaji', 30: 'aadhira', 99: 'jothi'}

# %%
d={10:'priya',20:'balaji',30:'aadhira'}
print("ols dictionary:",d)
d[30]='chandhu'
print("updated dictionary 3:chandhu:",d)
# Out:
# ols dictionary: {10: 'priya', 20: 'balaji', 30: 'aadhira'}
# updated dictionary 3:chandhu: {10: 'priya', 20: 'balaji', 30: 'chandhu'}

# %%
d={10:"priya",20:"balaji",30:"aadhira"}
print("Before deleting key from dictionary:",d)
del d[10]
print("After deleting key from dictionary:",d)
# Out:
# Before deleting key from dictionary: {10: 'priya', 20: 'balaji', 30: 'aadhira'}
# After deleting key from dictionary: {20: 'balaji', 30: 'aadhira'}

# %%
d={10:"priya",20:"balaji",30:"aadhira"}
print(d)
del d
print(d)
# Out:
# {10: 'priya', 20: 'balaji', 30: 'aadhira'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1573/2188109362.py in <cell line: 0>()
#       2 print(d)
#       3 del d
# ----> 4 print(d)
#
# NameError: name 'd' is not defined

# %%
d={100:"priya",200:"balaji"}
print("lenght of dictionary is:",len(d))
# Out:
# lenght of dictionary is: 2

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
d={10:"raji",20:"kaviya",30:"jothi"}
print(d)
d.clear()
print("after cleared entries in dictionary:",d)
# Out:
# {10: 'raji', 20: 'kaviya', 30: 'jothi'}
# after cleared entries in dictionary: {}

# %%
d={100:"preethe",200:"suganya",300:"sivaranjini"}
print(d)
print(d.values())
# Out:
# {100: 'preethe', 200: 'suganya', 300: 'sivaranjini'}
# dict_values(['preethe', 'suganya', 'sivaranjini'])

# %%
d={100:"preetha",200:"suganya",300:"sivaranjini"}
print(d)
print(d.keys())
# Out:
# {100: 'preetha', 200: 'suganya', 300: 'sivaranjini'}
# dict_keys([100, 200, 300])

# %%
d={100:"priya",200:"balaji",300:"jothi"}
print(d)
for r,s in d.items():
  print(r,s)
# Out:
# {100: 'priya', 200: 'balaji', 300: 'jothi'}
# 100 priya
# 200 balaji
# 300 jothi

# %%
squares={a:a*a for a in range(1,6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
