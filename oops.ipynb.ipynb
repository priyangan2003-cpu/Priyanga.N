# %%
a=[{"id":1,"title":"vish"},{"id":2,"title":"sat"}]
print(a)
def returns(res):
  return res["id"]==1

b= filter(lambda x:returns(x),a)
print(list(b))
# Out:
# [{'id': 1, 'title': 'vish'}, {'id': 2, 'title': 'sat'}]
# [{'id': 1, 'title': 'vish'}]

# %%
#creating a class and object
class Employee:
  def display(self):
        print("Hellow my name is Daniel")
emp=Employee()
emp.display()
# Out:
# Hellow my name is Daniel

# %%
#creating a class and object
class Employee:
  def display(self):
        print("Hellow my name is priynga")
  def teaching(self):
        print("i like teaching")
emp=Employee()
emp.display()
emp.teaching()
# Out:
# Hellow my name is priynga
# i like teaching

# %%
#Creating a constructor
class Employee:
  def __init__(self):
        print("constructor is ececuted")
emp=Employee()
# Out:
# constructor is ececuted

# %%
#Creating a constructor
class Employee:
  def __init__(self):
        print("constructor is ececuted")
emp1=Employee()
emp2=Employee()
# Out:
# constructor is ececuted
# constructor is ececuted

# %%
#one parameterised constructor
class Employee:
      def __init__(self,number):
            self.number=number
            print("Employee id is:",self.number)

e1=Employee(1)
e2=Employee(2)
e3=Employee(3)
# Out:
# Employee id is: 1
# Employee id is: 2
# Employee id is: 3

# %%
class Employee:
  def __init__(self,number):
    self.number=number
  def display(self):
    print("Employee id is:",self.number)
e1=Employee(1)
e2=Employee(2)
e3=Employee(3)
e1.display()
e2.display()
e3.display()
# Out:
# Employee id is: 1
# Employee id is: 2
# Employee id is: 3

# %%
#Two parameterised constructor and instance method
class Employee:
  def __init__(self,number,name):
    self.number=number
    self.name=name
  def display(self):
    print("Hellow my id is:",self.number)
    print("My name is:",self.name)
e1=Employee(1,'Priya')
e1.display()
e2=Employee(2,'Balaji')
e2.display()
# Out:
# Hellow my id is: 1
# My name is: Priya
# Hellow my id is: 2
# My name is: Balaji

# %%
#Three parameterised constructor and instance method
class Employee:
  def __init__(self,number,name,age):
    self.number=number
    self.name=name
    self.age=age
  def display(self):
    print("Hellow my id is:",self.number)
    print("My name is:",self.name)
    print("My age is sweet:",self.age)
e1=Employee(1,'Daniel',16)
e1.display()
e2=Employee(2,'Arjun',17)
e2.display()
e3=Employee(3,'prasad',18)
e3.display()
# Out:
# Hellow my id is: 1
# My name is: Daniel
# My age is sweet: 16
# Hellow my id is: 2
# My name is: Arjun
# My age is sweet: 17
# Hellow my id is: 3
# My name is: prasad
# My age is sweet: 18

# %%
#instance variables
class Student:
  def __init__(self,name,number):
    self.name=name
    self.number=number
s1=Student('Daniel',101)
s2=Student('prased',102)
print("Studen1 info:")
print("name:",s1.name)
print("id:",s2.number)
print("studen2 info:")
print("name:",s2.name)
print("id:",s2.number)
# Out:
# Studen1 info:
# name: Daniel
# id: 102
# studen2 info:
# name: prased
# id: 102

# %%
#initializing instance variables inside constructor
class Employee:
  def __init__(self):
    self.eno=10
    self.ename="priya"
    self.esal=10000
emp=Employee()
print("Employee number:",emp.eno)
print("employee name:",emp.ename)
print("Employee salary:",emp.esal)
# Out:
# Employee number: 10
# employee name: priya
# Employee salary: 10000

# %%
#instance methods
class Demo:
  def __init__(self,a):
    self.a=a
  def m(self):
    print(self.a)
d=Demo(10)
d.m()
# Out:
# 10
