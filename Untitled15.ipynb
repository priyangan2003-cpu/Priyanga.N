# %% [markdown]
# <a href="https://colab.research.google.com/github/priyangan2003-cpu/Priyanga.N/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
employee_ids=(10,20,30,40,50)
print("same type of object:",employee_ids)
print(type(employee_ids))
# Out:
# same type of object: (10, 20, 30, 40, 50)
# <class 'tuple'>

# %%
number=(9)
print(number)
print(type(number))
# Out:
# 9
# <class 'int'>

# %%
name=("Deniel")
print(name)
print(type(name))
# Out:
# Deniel
# <class 'str'>

# %%
name=("Deniel",)
print(name)
print(type(name))
# Out:
# ('Deniel',)
# <class 'tuple'>

# %%
emp_ids=10,20,30,40
print(emp_ids)
# Out:
# (10, 20, 30, 40)

# %%
emp_id=()
print(emp_id)
print(type(emp_id))
# Out:
# ()
# <class 'tuple'>

# %%
emp_id=(11,12,13)
std_id=120,130,140
print(emp_id)
print(std_id)
# Out:
# (11, 12, 13)
# (120, 130, 140)

# %%
t=(11,12,13,"deniel")
print(t)
# Out:
# (11, 12, 13, 'deniel')

# %%
a=[11,22,33]
t=tuple(a)
print(t)
# Out:
# (11, 22, 33)

# %%
t=(10,20,30,40,50,60)
print(t[0])
print(t[-1])
# Out:
# 10
# 60

# %%
t=(10,20,30,40,50,60)
print(t[2:5])
print(t[2:100])
print(t[::3])
# Out:
# (30, 40, 50)
# (30, 40, 50, 60)
# (10, 40)

# %%
t=(10,20,30,40)
print(t[1])
t[1]=70
# Out:
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1166/3846552646.py in <cell line: 0>()
#       1 t=(10,20,30,40)
#       2 print(t[1])
# ----> 3 t[1]=70
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(10,20,30)
t2=(40,50,60)
t3=t1+t2
print(t3)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t1=(10,20,30)
t2=t1*3
print(t2)
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t=(10,20,30,40)
print(len(t))
# Out:
# 4

# %%
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
t=(10,20,10,10,20)
print(t.count(10))
# Out:
# 3

# %%
t=(10,20,30)
print(t.index(30))
# Out:
# 2

# %%
t=(10,20,30)
print(t.index(88))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1166/1721440455.py in <cell line: 0>()
#       1 t=(10,20,30)
# ----> 2 print(t.index(88))
#
# ValueError: tuple.index(x): x not in tuple

# %%
t=(11,22,[33,44],55,66)
t[2].append(77)
print(t)
# Out:
# (11, 22, [33, 44, 77], 55, 66)
