# %%
def add(a,b):
  c=a+b
  print(c)
x=10
y=15
add(x,y)
# Out:
# 25

# %%
def sub(x,y):
  print(x-y)
sub(30,10)
# Out:
# 20

# %%
def sub(x,y):
  print(x-y)
sub(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2064/2425928821.py in <cell line: 0>()
#       1 def sub(x,y):
#       2   print(x-y)
# ----> 3 sub(10,20,30)
#
# TypeError: sub() takes 2 positional arguments but 3 were given

# %%
def cart(product,price):
  print("product is:",product)
  print("costis:",price)
cart(product="bangles",price=20000)
# Out:
# product is: bangles
# costis: 20000

# %%
def cart(product,price):
  print("product is:",product)
  print("cost is:",price)
cart(product="handbag",price=100000)
# Out:
# product is: handbag
# cost is: 100000

# %%
def cart(product,price):
  print("product is:",product)
  print("cost is:",price)
cart(price=1200,product="shirt")
# Out:
# product is: shirt
# cost is: 1200

# %%
def cart(product ,price=40.0):
  print("product is :",product)
  print("cost is :",price)
cart(product="pen")
# Out:
# product is : pen
# cost is : 40.0

# %%
def cart(product,price=40.0):
  print("product is :",product)
  print("cost is :",price)
cart(product="pen")
# Out:
# product is : pen
# cost is : 40.0

# %%
def crt(product,price=40.0):
  print("product is :",product)
  print("cost is :",price)
cart(product="handbag",price=10000)
# Out:
# product is : handbag
# cost is : 10000

# %%
def crt(product,price=40.0):
  print("product is :",product)
  print("cost is :",price)
cart(price=500,product="shirt")
# Out:
# product is : shirt
# cost is : 500

# %%
def m(x):
  print(x)
m(10)
# Out:
# 10

# %%
def m(x):
  print(x)
m(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2064/127779254.py in <cell line: 0>()
#       1 def m(x):
#       2   print(x)
# ----> 3 m(10,20)
#
# TypeError: m() takes 1 positional argument but 2 were given

# %%
def m(*x):
  print(x)
m(10)
# Out:
# (10,)

# %%
def m(*x):
  print(x)
m(12,20)
# Out:
# (12, 20)

# %%
def m(*x):
  print(x)
m(10,20,30)
# Out:
# (10, 20, 30)

# %%
s=lambda a:a*a
x=s(4)
print(x)
# Out:
# 16

# %%
def square(t):
  return t*t
s=square(2)
print(s)
# Out:
# 4

# %%
def add(x,y):
  return x+y
b=add(2,3)
print(b)
# Out:
# 5

# %%
add=lambda x,y:x+y
result=add(1,2)
print("the sum of value is:",result)
# Out:
# the sum of value is: 3

# %%
without_gst_cost=[100,200,300,400]
with_gst_cost=map(lambda x:x+10,without_gst_cost)
x=list(with_gst_cost)
print("without gst item cost:",without_gst_cost)
print("with gst item cost:",x)
# Out:
# without gst item cost: [100, 200, 300, 400]
# with gst item cost: [110, 210, 310, 410]

# %%
items_cost=[999,888,1100,1200,1300,777]
gt_thousand=filter(lambda x:x>1000,items_cost)
x=list(gt_thousand)
print("eligible for discount:",x)
# Out:
# eligible for discount: [1100, 1200, 1300]

# %%
from functools import reduce
item_cost=[111,222,333,444]
totl_cost=reduce(lambda x,y:x+y,item_cost)
print(totl_cost)
# Out:
# 1110
